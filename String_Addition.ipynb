# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a234-source/python/blob/main/String_Addition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = 'We'
B = ' Want'
C = ' Leetcode!'
print(A + B + C)
press = input()
str = 'name'
name = 'Mr. Black!'
print(name)
print('K value?')
k = 1000
print(k)
print(type(name))
print(type(k))
print(type(press))
# Out:
# We Want Leetcode!
# Who Am I?
# Mr. Black!
# K value?
# 1000
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
